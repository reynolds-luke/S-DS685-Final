# %%
# FOR USE IN CONJUNCTION WITH https://github.com/lweitkamp/feudalnets-pytorch


# fun_minigrid_train.py
"""
Minimal Feudal Network (FuN) training script for the MiniGrid environment.

Runs in a single Jupyter cell.
Prints average extrinsic reward every 10 epochs.
"""

import gymnasium as gym
import numpy as np
import torch
from types import SimpleNamespace

# Import wrappers from the MiniGrid package
from minigrid.wrappers import RGBImgObsWrapper, ImgObsWrapper

import numpy as np
import torch
import torch
import torch.nn.functional as F
from torch.distributions import Categorical


def take_action(action_logits):
    probs = F.softmax(action_logits, dim=-1)
    dist = Categorical(probs)
    action = dist.sample()
    log_prob = dist.log_prob(action)
    entropy = dist.entropy()
    return action.cpu().numpy(), log_prob, entropy


class ReturnWrapper:
    def __init__(self, env):
        self.env = env

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        done = np.logical_or(terminated, truncated)

        # Enforce that `info` is a list of dicts
        if isinstance(info, list):
            fixed_info = []
            for i in range(len(info)):
                entry = info[i] if isinstance(info[i], dict) else {}
                entry = entry.copy()
                if done[i]:
                    entry["returns/episodic_reward"] = reward[i]
                fixed_info.append(entry)
            info = fixed_info
        else:
            # Single environment case (shouldn't happen in SyncVectorEnv)
            info = {} if not isinstance(info, dict) else info.copy()
            if done:
                info["returns/episodic_reward"] = reward

        return obs, reward, terminated, truncated, info

    def __getattr__(self, name):
        return getattr(self.env, name)



from storage import Storage
from feudalnet import FeudalNetwork, feudal_loss


def make_minigrid_envs(env_name: str, num_envs: int, seed: int = 0):
    """Create vectorised MiniGrid environments that output 84×84 RGB frames."""
    def make_env(rank: int):
        def _thunk():
            env = gym.make(env_name)
            env = RGBImgObsWrapper(env, tile_size=14)
            env = ImgObsWrapper(env)
            env = ReturnWrapper(env)
            env.reset(seed=seed + rank)
            return env
        return _thunk

    return gym.vector.SyncVectorEnv([make_env(i) for i in range(num_envs)])



args = SimpleNamespace(
    env_name="MiniGrid-Empty-Random-6x6-v0",
    num_workers=8,
    num_steps=64,
    epochs=50_000,
    seed=0,
    lr=5e-4,
    grad_clip=5.0,
    entropy_coef=0.01,
    time_horizon=10,
    hidden_dim_manager=128,
    hidden_dim_worker=16,
    gamma_w=0.99,
    gamma_m=0.999,
    alpha=0.5,
    eps=1e-5,
    dilation=10,
    mlp=0,
    cuda=torch.cuda.is_available(),
)
device = torch.device("cuda" if args.cuda else "cpu")
args.device = device
torch.manual_seed(args.seed)
np.random.seed(args.seed)

envs = make_minigrid_envs(args.env_name, args.num_workers, args.seed)
feudalnet = FeudalNetwork(
    num_workers=args.num_workers,
    input_dim=envs.single_observation_space.shape,
    hidden_dim_manager=args.hidden_dim_manager,
    hidden_dim_worker=args.hidden_dim_worker,
    n_actions=envs.single_action_space.n,
    time_horizon=args.time_horizon,
    dilation=args.dilation,
    device=device,
    mlp=args.mlp,
    args=args,
)
optimizer = torch.optim.RMSprop(
    feudalnet.parameters(), lr=args.lr, alpha=0.99, eps=1e-5
)

goals, states, masks = feudalnet.init_obj()
obs, _ = envs.reset()

episode_rewards_history = []
epoch_rewards_history = []

for epoch in range(1, args.epochs + 1):
    feudalnet.repackage_hidden()
    goals = [g.detach() for g in goals]

    storage = Storage(
        size=args.num_steps,
        keys=["r", "r_i", "v_w", "v_m", "logp", "entropy",
                "s_goal_cos", "m", "ret_w", "ret_m", "adv_m", "adv_w"],
    )

    epoch_rewards = []

    for _ in range(args.num_steps):
        action_dist, goals, states, value_m, value_w = feudalnet(
            obs, goals, states, masks[-1]
        )
        actions, logp, entropy = take_action(action_dist)
        obs, reward, terminated, truncated, infos = envs.step(actions)
        done = np.logical_or(terminated, truncated)

        for i, info in enumerate(infos):
            episode_rewards_history.append(reward[i])
            epoch_rewards.append(reward[i])


        mask = torch.FloatTensor(1 - done).unsqueeze(-1).to(device)
        masks.pop(0)
        masks.append(mask)

        storage.add({
            "r": torch.FloatTensor(reward).unsqueeze(-1).to(device),
            "r_i": feudalnet.intrinsic_reward(states, goals, masks),
            "v_w": value_w,
            "v_m": value_m,
            "logp": logp.unsqueeze(-1),
            "entropy": entropy.unsqueeze(-1),
            "s_goal_cos": feudalnet.state_goal_cosine(states, goals, masks),
            "m": mask,
        })

    with torch.no_grad():
        *_, next_v_m, next_v_w = feudalnet(obs, goals, states, mask, save=False)

    optimizer.zero_grad()
    loss, _ = feudal_loss(storage, next_v_m.detach(), next_v_w.detach(), args)
    loss.backward()
    torch.nn.utils.clip_grad_norm_(feudalnet.parameters(), args.grad_clip)
    optimizer.step()

    epoch_rewards_history.append(epoch_rewards)
    if epoch % 10 == 0:
        last_10_rewards = [r for sub in epoch_rewards_history[-10:] for r in sub]
        if last_10_rewards:
            avg = np.mean(last_10_rewards)
            print(f"Epoch {epoch:4d} | average extrinsic reward (last 10 epochs): {avg:.3f}")
        else:
            print(f"Epoch {epoch:4d} | no episodes completed in the last 10 epochs")

envs.close()
# Out:
# Epoch   10 | average extrinsic reward (last 10 epochs): 0.053
# Epoch   20 | average extrinsic reward (last 10 epochs): 0.013
# Epoch   30 | average extrinsic reward (last 10 epochs): 0.038
# Epoch   40 | average extrinsic reward (last 10 epochs): 0.032
# Epoch   50 | average extrinsic reward (last 10 epochs): 0.035
# Epoch   60 | average extrinsic reward (last 10 epochs): 0.031
# Epoch   70 | average extrinsic reward (last 10 epochs): 0.035
# Epoch   80 | average extrinsic reward (last 10 epochs): 0.060
# Epoch   90 | average extrinsic reward (last 10 epochs): 0.034
# Epoch  100 | average extrinsic reward (last 10 epochs): 0.036
# Epoch  110 | average extrinsic reward (last 10 epochs): 0.058
# Epoch  120 | average extrinsic reward (last 10 epochs): 0.067
# Epoch  130 | average extrinsic reward (last 10 epochs): 0.052
# Epoch  140 | average extrinsic reward (last 10 epochs): 0.043
# Epoch  150 | average extrinsic reward (last 10 epochs): 0.045
# Epoch  160 | average extrinsic reward (last 10 epochs): 0.068
# Epoch  170 | average extrinsic reward (last 10 epochs): 0.055
# Epoch  180 | average extrinsic reward (last 10 epochs): 0.058
# Epoch  190 | average extrinsic reward (last 10 epochs): 0.054
# Epoch  200 | average extrinsic reward (last 10 epochs): 0.063
# Epoch  210 | average extrinsic reward (last 10 epochs): 0.037
# Epoch  220 | average extrinsic reward (last 10 epochs): 0.080
# Epoch  230 | average extrinsic reward (last 10 epochs): 0.068
# Epoch  240 | average extrinsic reward (last 10 epochs): 0.065
# Epoch  250 | average extrinsic reward (last 10 epochs): 0.027
# Epoch  260 | average extrinsic reward (last 10 epochs): 0.067
# Epoch  270 | average extrinsic reward (last 10 epochs): 0.040
# Epoch  280 | average extrinsic reward (last 10 epochs): 0.057
# Epoch  290 | average extrinsic reward (last 10 epochs): 0.088
# Epoch  300 | average extrinsic reward (last 10 epochs): 0.079
# Epoch  310 | average extrinsic reward (last 10 epochs): 0.081
# Epoch  320 | average extrinsic reward (last 10 epochs): 0.082
# Epoch  330 | average extrinsic reward (last 10 epochs): 0.070
# Epoch  340 | average extrinsic reward (last 10 epochs): 0.077
# Epoch  350 | average extrinsic reward (last 10 epochs): 0.098
# Epoch  360 | average extrinsic reward (last 10 epochs): 0.057
# Epoch  370 | average extrinsic reward (last 10 epochs): 0.096
# Epoch  380 | average extrinsic reward (last 10 epochs): 0.050
# Epoch  390 | average extrinsic reward (last 10 epochs): 0.048
# Epoch  400 | average extrinsic reward (last 10 epochs): 0.081
# Epoch  410 | average extrinsic reward (last 10 epochs): 0.092
# Epoch  420 | average extrinsic reward (last 10 epochs): 0.128
# Epoch  430 | average extrinsic reward (last 10 epochs): 0.085
# Epoch  440 | average extrinsic reward (last 10 epochs): 0.118
# Epoch  450 | average extrinsic reward (last 10 epochs): 0.100
# Epoch  460 | average extrinsic reward (last 10 epochs): 0.097
# Epoch  470 | average extrinsic reward (last 10 epochs): 0.129
# Epoch  480 | average extrinsic reward (last 10 epochs): 0.116
# Epoch  490 | average extrinsic reward (last 10 epochs): 0.075
# Epoch  500 | average extrinsic reward (last 10 epochs): 0.111
# Epoch  510 | average extrinsic reward (last 10 epochs): 0.084
# Epoch  520 | average extrinsic reward (last 10 epochs): 0.124
# Epoch  530 | average extrinsic reward (last 10 epochs): 0.078
# Epoch  540 | average extrinsic reward (last 10 epochs): 0.100
# Epoch  550 | average extrinsic reward (last 10 epochs): 0.100
# Epoch  560 | average extrinsic reward (last 10 epochs): 0.097
# Epoch  570 | average extrinsic reward (last 10 epochs): 0.114
# Epoch  580 | average extrinsic reward (last 10 epochs): 0.090
# Epoch  590 | average extrinsic reward (last 10 epochs): 0.115
# Epoch  600 | average extrinsic reward (last 10 epochs): 0.087
# Epoch  610 | average extrinsic reward (last 10 epochs): 0.127
# Epoch  620 | average extrinsic reward (last 10 epochs): 0.091
# Epoch  630 | average extrinsic reward (last 10 epochs): 0.105
# Epoch  640 | average extrinsic reward (last 10 epochs): 0.080
# Epoch  650 | average extrinsic reward (last 10 epochs): 0.121
# Epoch  660 | average extrinsic reward (last 10 epochs): 0.089
# Epoch  670 | average extrinsic reward (last 10 epochs): 0.100
# Epoch  680 | average extrinsic reward (last 10 epochs): 0.082
# Epoch  690 | average extrinsic reward (last 10 epochs): 0.116
# Epoch  700 | average extrinsic reward (last 10 epochs): 0.083
# Epoch  710 | average extrinsic reward (last 10 epochs): 0.108
# Epoch  720 | average extrinsic reward (last 10 epochs): 0.095
# Epoch  730 | average extrinsic reward (last 10 epochs): 0.111
# Epoch  740 | average extrinsic reward (last 10 epochs): 0.100
# Epoch  750 | average extrinsic reward (last 10 epochs): 0.100
# Epoch  760 | average extrinsic reward (last 10 epochs): 0.110
# Epoch  770 | average extrinsic reward (last 10 epochs): 0.106
# Epoch  780 | average extrinsic reward (last 10 epochs): 0.135
# Epoch  790 | average extrinsic reward (last 10 epochs): 0.131
# Epoch  800 | average extrinsic reward (last 10 epochs): 0.115
# Epoch  810 | average extrinsic reward (last 10 epochs): 0.119
# Epoch  820 | average extrinsic reward (last 10 epochs): 0.090
# Epoch  830 | average extrinsic reward (last 10 epochs): 0.091
# Epoch  840 | average extrinsic reward (last 10 epochs): 0.127
# Epoch  850 | average extrinsic reward (last 10 epochs): 0.112
# Epoch  860 | average extrinsic reward (last 10 epochs): 0.095
# Epoch  870 | average extrinsic reward (last 10 epochs): 0.115
# Epoch  880 | average extrinsic reward (last 10 epochs): 0.079
# Epoch  890 | average extrinsic reward (last 10 epochs): 0.104
# Epoch  900 | average extrinsic reward (last 10 epochs): 0.078
# Epoch  910 | average extrinsic reward (last 10 epochs): 0.102
# Epoch  920 | average extrinsic reward (last 10 epochs): 0.158
# Epoch  930 | average extrinsic reward (last 10 epochs): 0.104
# Epoch  940 | average extrinsic reward (last 10 epochs): 0.121
# Epoch  950 | average extrinsic reward (last 10 epochs): 0.124
# Epoch  960 | average extrinsic reward (last 10 epochs): 0.104
# Epoch  970 | average extrinsic reward (last 10 epochs): 0.125
# Epoch  980 | average extrinsic reward (last 10 epochs): 0.102
# Epoch  990 | average extrinsic reward (last 10 epochs): 0.114
# Epoch 1000 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 1010 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 1020 | average extrinsic reward (last 10 epochs): 0.138
# Epoch 1030 | average extrinsic reward (last 10 epochs): 0.114
# Epoch 1040 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 1050 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 1060 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 1070 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 1080 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 1090 | average extrinsic reward (last 10 epochs): 0.129
# Epoch 1100 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 1110 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 1120 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 1130 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 1140 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 1150 | average extrinsic reward (last 10 epochs): 0.119
# Epoch 1160 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 1170 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 1180 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 1190 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 1200 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 1210 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 1220 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 1230 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 1240 | average extrinsic reward (last 10 epochs): 0.111
# Epoch 1250 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 1260 | average extrinsic reward (last 10 epochs): 0.112
# Epoch 1270 | average extrinsic reward (last 10 epochs): 0.113
# Epoch 1280 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 1290 | average extrinsic reward (last 10 epochs): 0.109
# Epoch 1300 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 1310 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 1320 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 1330 | average extrinsic reward (last 10 epochs): 0.124
# Epoch 1340 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 1350 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 1360 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 1370 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 1380 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 1390 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 1400 | average extrinsic reward (last 10 epochs): 0.117
# Epoch 1410 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 1420 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 1430 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 1440 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 1450 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 1460 | average extrinsic reward (last 10 epochs): 0.127
# Epoch 1470 | average extrinsic reward (last 10 epochs): 0.131
# Epoch 1480 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 1490 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 1500 | average extrinsic reward (last 10 epochs): 0.116
# Epoch 1510 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 1520 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 1530 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 1540 | average extrinsic reward (last 10 epochs): 0.129
# Epoch 1550 | average extrinsic reward (last 10 epochs): 0.056
# Epoch 1560 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 1570 | average extrinsic reward (last 10 epochs): 0.114
# Epoch 1580 | average extrinsic reward (last 10 epochs): 0.118
# Epoch 1590 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 1600 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 1610 | average extrinsic reward (last 10 epochs): 0.113
# Epoch 1620 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 1630 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 1640 | average extrinsic reward (last 10 epochs): 0.109
# Epoch 1650 | average extrinsic reward (last 10 epochs): 0.125
# Epoch 1660 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 1670 | average extrinsic reward (last 10 epochs): 0.126
# Epoch 1680 | average extrinsic reward (last 10 epochs): 0.134
# Epoch 1690 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 1700 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 1710 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 1720 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 1730 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 1740 | average extrinsic reward (last 10 epochs): 0.133
# Epoch 1750 | average extrinsic reward (last 10 epochs): 0.055
# Epoch 1760 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 1770 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 1780 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 1790 | average extrinsic reward (last 10 epochs): 0.113
# Epoch 1800 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 1810 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 1820 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 1830 | average extrinsic reward (last 10 epochs): 0.115
# Epoch 1840 | average extrinsic reward (last 10 epochs): 0.137
# Epoch 1850 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 1860 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 1870 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 1880 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 1890 | average extrinsic reward (last 10 epochs): 0.115
# Epoch 1900 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 1910 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 1920 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 1930 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 1940 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 1950 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 1960 | average extrinsic reward (last 10 epochs): 0.064
# Epoch 1970 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 1980 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 1990 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 2000 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 2010 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 2020 | average extrinsic reward (last 10 epochs): 0.119
# Epoch 2030 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 2040 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 2050 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 2060 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 2070 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 2080 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 2090 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 2100 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 2110 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 2120 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 2130 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 2140 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 2150 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 2160 | average extrinsic reward (last 10 epochs): 0.111
# Epoch 2170 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 2180 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 2190 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 2200 | average extrinsic reward (last 10 epochs): 0.124
# Epoch 2210 | average extrinsic reward (last 10 epochs): 0.104
# Epoch 2220 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 2230 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 2240 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 2250 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 2260 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 2270 | average extrinsic reward (last 10 epochs): 0.113
# Epoch 2280 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 2290 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 2300 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 2310 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 2320 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 2330 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 2340 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 2350 | average extrinsic reward (last 10 epochs): 0.064
# Epoch 2360 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 2370 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 2380 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 2390 | average extrinsic reward (last 10 epochs): 0.124
# Epoch 2400 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 2410 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 2420 | average extrinsic reward (last 10 epochs): 0.056
# Epoch 2430 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 2440 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 2450 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 2460 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 2470 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 2480 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 2490 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 2500 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 2510 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 2520 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 2530 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 2540 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 2550 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 2560 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 2570 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 2580 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 2590 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 2600 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 2610 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 2620 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 2630 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 2640 | average extrinsic reward (last 10 epochs): 0.118
# Epoch 2650 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 2660 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 2670 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 2680 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 2690 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 2700 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 2710 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 2720 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 2730 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 2740 | average extrinsic reward (last 10 epochs): 0.047
# Epoch 2750 | average extrinsic reward (last 10 epochs): 0.051
# Epoch 2760 | average extrinsic reward (last 10 epochs): 0.007
# Epoch 2770 | average extrinsic reward (last 10 epochs): 0.006
# Epoch 2780 | average extrinsic reward (last 10 epochs): 0.040
# Epoch 2790 | average extrinsic reward (last 10 epochs): 0.002
# Epoch 2800 | average extrinsic reward (last 10 epochs): 0.019
# Epoch 2810 | average extrinsic reward (last 10 epochs): 0.017
# Epoch 2820 | average extrinsic reward (last 10 epochs): 0.046
# Epoch 2830 | average extrinsic reward (last 10 epochs): 0.024
# Epoch 2840 | average extrinsic reward (last 10 epochs): 0.029
# Epoch 2850 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 2860 | average extrinsic reward (last 10 epochs): 0.019
# Epoch 2870 | average extrinsic reward (last 10 epochs): 0.047
# Epoch 2880 | average extrinsic reward (last 10 epochs): 0.025
# Epoch 2890 | average extrinsic reward (last 10 epochs): 0.045
# Epoch 2900 | average extrinsic reward (last 10 epochs): 0.038
# Epoch 2910 | average extrinsic reward (last 10 epochs): 0.051
# Epoch 2920 | average extrinsic reward (last 10 epochs): 0.045
# Epoch 2930 | average extrinsic reward (last 10 epochs): 0.038
# Epoch 2940 | average extrinsic reward (last 10 epochs): 0.032
# Epoch 2950 | average extrinsic reward (last 10 epochs): 0.025
# Epoch 2960 | average extrinsic reward (last 10 epochs): 0.034
# Epoch 2970 | average extrinsic reward (last 10 epochs): 0.018
# Epoch 2980 | average extrinsic reward (last 10 epochs): 0.042
# Epoch 2990 | average extrinsic reward (last 10 epochs): 0.013
# Epoch 3000 | average extrinsic reward (last 10 epochs): 0.011
# Epoch 3010 | average extrinsic reward (last 10 epochs): 0.030
# Epoch 3020 | average extrinsic reward (last 10 epochs): 0.045
# Epoch 3030 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 3040 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 3050 | average extrinsic reward (last 10 epochs): 0.115
# Epoch 3060 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 3070 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 3080 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 3090 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 3100 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 3110 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 3120 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 3130 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 3140 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 3150 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 3160 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 3170 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 3180 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 3190 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 3200 | average extrinsic reward (last 10 epochs): 0.043
# Epoch 3210 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 3220 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 3230 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 3240 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 3250 | average extrinsic reward (last 10 epochs): 0.053
# Epoch 3260 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 3270 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 3280 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 3290 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 3300 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 3310 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 3320 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 3330 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 3340 | average extrinsic reward (last 10 epochs): 0.054
# Epoch 3350 | average extrinsic reward (last 10 epochs): 0.120
# Epoch 3360 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 3370 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 3380 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 3390 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 3400 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 3410 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 3420 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 3430 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 3440 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 3450 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 3460 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 3470 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 3480 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 3490 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 3500 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 3510 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 3520 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 3530 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 3540 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 3550 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 3560 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 3570 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 3580 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 3590 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 3600 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 3610 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 3620 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 3630 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 3640 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 3650 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 3660 | average extrinsic reward (last 10 epochs): 0.029
# Epoch 3670 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 3680 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 3690 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 3700 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 3710 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 3720 | average extrinsic reward (last 10 epochs): 0.111
# Epoch 3730 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 3740 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 3750 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 3760 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 3770 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 3780 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 3790 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 3800 | average extrinsic reward (last 10 epochs): 0.042
# Epoch 3810 | average extrinsic reward (last 10 epochs): 0.136
# Epoch 3820 | average extrinsic reward (last 10 epochs): 0.061
# Epoch 3830 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 3840 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 3850 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 3860 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 3870 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 3880 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 3890 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 3900 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 3910 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 3920 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 3930 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 3940 | average extrinsic reward (last 10 epochs): 0.054
# Epoch 3950 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 3960 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 3970 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 3980 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 3990 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 4000 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 4010 | average extrinsic reward (last 10 epochs): 0.051
# Epoch 4020 | average extrinsic reward (last 10 epochs): 0.058
# Epoch 4030 | average extrinsic reward (last 10 epochs): 0.051
# Epoch 4040 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 4050 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 4060 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 4070 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 4080 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 4090 | average extrinsic reward (last 10 epochs): 0.120
# Epoch 4100 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 4110 | average extrinsic reward (last 10 epochs): 0.052
# Epoch 4120 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 4130 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 4140 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 4150 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 4160 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 4170 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 4180 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 4190 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 4200 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 4210 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 4220 | average extrinsic reward (last 10 epochs): 0.048
# Epoch 4230 | average extrinsic reward (last 10 epochs): 0.107
# Epoch 4240 | average extrinsic reward (last 10 epochs): 0.104
# Epoch 4250 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 4260 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 4270 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 4280 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 4290 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 4300 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 4310 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 4320 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 4330 | average extrinsic reward (last 10 epochs): 0.123
# Epoch 4340 | average extrinsic reward (last 10 epochs): 0.121
# Epoch 4350 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 4360 | average extrinsic reward (last 10 epochs): 0.050
# Epoch 4370 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 4380 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 4390 | average extrinsic reward (last 10 epochs): 0.061
# Epoch 4400 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 4410 | average extrinsic reward (last 10 epochs): 0.056
# Epoch 4420 | average extrinsic reward (last 10 epochs): 0.052
# Epoch 4430 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 4440 | average extrinsic reward (last 10 epochs): 0.058
# Epoch 4450 | average extrinsic reward (last 10 epochs): 0.059
# Epoch 4460 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 4470 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 4480 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 4490 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 4500 | average extrinsic reward (last 10 epochs): 0.132
# Epoch 4510 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 4520 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 4530 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 4540 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 4550 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 4560 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 4570 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 4580 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 4590 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 4600 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 4610 | average extrinsic reward (last 10 epochs): 0.056
# Epoch 4620 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 4630 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 4640 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 4650 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 4660 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 4670 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 4680 | average extrinsic reward (last 10 epochs): 0.054
# Epoch 4690 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 4700 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 4710 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 4720 | average extrinsic reward (last 10 epochs): 0.056
# Epoch 4730 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 4740 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 4750 | average extrinsic reward (last 10 epochs): 0.053
# Epoch 4760 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 4770 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 4780 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 4790 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 4800 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 4810 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 4820 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 4830 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 4840 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 4850 | average extrinsic reward (last 10 epochs): 0.053
# Epoch 4860 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 4870 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 4880 | average extrinsic reward (last 10 epochs): 0.050
# Epoch 4890 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 4900 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 4910 | average extrinsic reward (last 10 epochs): 0.130
# Epoch 4920 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 4930 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 4940 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 4950 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 4960 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 4970 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 4980 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 4990 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 5000 | average extrinsic reward (last 10 epochs): 0.061
# Epoch 5010 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 5020 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 5030 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 5040 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 5050 | average extrinsic reward (last 10 epochs): 0.043
# Epoch 5060 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 5070 | average extrinsic reward (last 10 epochs): 0.048
# Epoch 5080 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 5090 | average extrinsic reward (last 10 epochs): 0.109
# Epoch 5100 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 5110 | average extrinsic reward (last 10 epochs): 0.058
# Epoch 5120 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 5130 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 5140 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 5150 | average extrinsic reward (last 10 epochs): 0.133
# Epoch 5160 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 5170 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 5180 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 5190 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 5200 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 5210 | average extrinsic reward (last 10 epochs): 0.056
# Epoch 5220 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 5230 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 5240 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 5250 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 5260 | average extrinsic reward (last 10 epochs): 0.135
# Epoch 5270 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 5280 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 5290 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 5300 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 5310 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 5320 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 5330 | average extrinsic reward (last 10 epochs): 0.056
# Epoch 5340 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 5350 | average extrinsic reward (last 10 epochs): 0.064
# Epoch 5360 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 5370 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 5380 | average extrinsic reward (last 10 epochs): 0.054
# Epoch 5390 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 5400 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 5410 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 5420 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 5430 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 5440 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 5450 | average extrinsic reward (last 10 epochs): 0.050
# Epoch 5460 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 5470 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 5480 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 5490 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 5500 | average extrinsic reward (last 10 epochs): 0.132
# Epoch 5510 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 5520 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 5530 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 5540 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 5550 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 5560 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 5570 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 5580 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 5590 | average extrinsic reward (last 10 epochs): 0.061
# Epoch 5600 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 5610 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 5620 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 5630 | average extrinsic reward (last 10 epochs): 0.031
# Epoch 5640 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 5650 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 5660 | average extrinsic reward (last 10 epochs): 0.127
# Epoch 5670 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 5680 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 5690 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 5700 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 5710 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 5720 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 5730 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 5740 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 5750 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 5760 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 5770 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 5780 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 5790 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 5800 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 5810 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 5820 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 5830 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 5840 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 5850 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 5860 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 5870 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 5880 | average extrinsic reward (last 10 epochs): 0.112
# Epoch 5890 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 5900 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 5910 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 5920 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 5930 | average extrinsic reward (last 10 epochs): 0.134
# Epoch 5940 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 5950 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 5960 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 5970 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 5980 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 5990 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 6000 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 6010 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 6020 | average extrinsic reward (last 10 epochs): 0.055
# Epoch 6030 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 6040 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 6050 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 6060 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 6070 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 6080 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 6090 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 6100 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 6110 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 6120 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 6130 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 6140 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 6150 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 6160 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 6170 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 6180 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 6190 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 6200 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 6210 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 6220 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 6230 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 6240 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 6250 | average extrinsic reward (last 10 epochs): 0.109
# Epoch 6260 | average extrinsic reward (last 10 epochs): 0.104
# Epoch 6270 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 6280 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 6290 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 6300 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 6310 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 6320 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 6330 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 6340 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 6350 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 6360 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 6370 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 6380 | average extrinsic reward (last 10 epochs): 0.129
# Epoch 6390 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 6400 | average extrinsic reward (last 10 epochs): 0.129
# Epoch 6410 | average extrinsic reward (last 10 epochs): 0.116
# Epoch 6420 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 6430 | average extrinsic reward (last 10 epochs): 0.116
# Epoch 6440 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 6450 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 6460 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 6470 | average extrinsic reward (last 10 epochs): 0.104
# Epoch 6480 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 6490 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 6500 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 6510 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 6520 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 6530 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 6540 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 6550 | average extrinsic reward (last 10 epochs): 0.112
# Epoch 6560 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 6570 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 6580 | average extrinsic reward (last 10 epochs): 0.117
# Epoch 6590 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 6600 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 6610 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 6620 | average extrinsic reward (last 10 epochs): 0.117
# Epoch 6630 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 6640 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 6650 | average extrinsic reward (last 10 epochs): 0.036
# Epoch 6660 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 6670 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 6680 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 6690 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 6700 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 6710 | average extrinsic reward (last 10 epochs): 0.127
# Epoch 6720 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 6730 | average extrinsic reward (last 10 epochs): 0.124
# Epoch 6740 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 6750 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 6760 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 6770 | average extrinsic reward (last 10 epochs): 0.128
# Epoch 6780 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 6790 | average extrinsic reward (last 10 epochs): 0.115
# Epoch 6800 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 6810 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 6820 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 6830 | average extrinsic reward (last 10 epochs): 0.119
# Epoch 6840 | average extrinsic reward (last 10 epochs): 0.124
# Epoch 6850 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 6860 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 6870 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 6880 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 6890 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 6900 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 6910 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 6920 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 6930 | average extrinsic reward (last 10 epochs): 0.104
# Epoch 6940 | average extrinsic reward (last 10 epochs): 0.107
# Epoch 6950 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 6960 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 6970 | average extrinsic reward (last 10 epochs): 0.045
# Epoch 6980 | average extrinsic reward (last 10 epochs): 0.119
# Epoch 6990 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 7000 | average extrinsic reward (last 10 epochs): 0.134
# Epoch 7010 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 7020 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 7030 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 7040 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 7050 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 7060 | average extrinsic reward (last 10 epochs): 0.129
# Epoch 7070 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 7080 | average extrinsic reward (last 10 epochs): 0.118
# Epoch 7090 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 7100 | average extrinsic reward (last 10 epochs): 0.053
# Epoch 7110 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 7120 | average extrinsic reward (last 10 epochs): 0.072
# Epoch 7130 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 7140 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 7150 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 7160 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 7170 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 7180 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 7190 | average extrinsic reward (last 10 epochs): 0.127
# Epoch 7200 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 7210 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 7220 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 7230 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 7240 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 7250 | average extrinsic reward (last 10 epochs): 0.119
# Epoch 7260 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 7270 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 7280 | average extrinsic reward (last 10 epochs): 0.094
# Epoch 7290 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 7300 | average extrinsic reward (last 10 epochs): 0.134
# Epoch 7310 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 7320 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 7330 | average extrinsic reward (last 10 epochs): 0.141
# Epoch 7340 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 7350 | average extrinsic reward (last 10 epochs): 0.147
# Epoch 7360 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 7370 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 7380 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 7390 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 7400 | average extrinsic reward (last 10 epochs): 0.112
# Epoch 7410 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 7420 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 7430 | average extrinsic reward (last 10 epochs): 0.104
# Epoch 7440 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 7450 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 7460 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 7470 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 7480 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 7490 | average extrinsic reward (last 10 epochs): 0.069
# Epoch 7500 | average extrinsic reward (last 10 epochs): 0.109
# Epoch 7510 | average extrinsic reward (last 10 epochs): 0.111
# Epoch 7520 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 7530 | average extrinsic reward (last 10 epochs): 0.121
# Epoch 7540 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 7550 | average extrinsic reward (last 10 epochs): 0.120
# Epoch 7560 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 7570 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 7580 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 7590 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 7600 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 7610 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 7620 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 7630 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 7640 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 7650 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 7660 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 7670 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 7680 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 7690 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 7700 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 7710 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 7720 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 7730 | average extrinsic reward (last 10 epochs): 0.113
# Epoch 7740 | average extrinsic reward (last 10 epochs): 0.053
# ...
# Epoch 13390 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 13400 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 13410 | average extrinsic reward (last 10 epochs): 0.115
# Epoch 13420 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 13430 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 13440 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 13450 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 13460 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 13470 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 13480 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 13490 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 13500 | average extrinsic reward (last 10 epochs): 0.107
# Epoch 13510 | average extrinsic reward (last 10 epochs): 0.045
# Epoch 13520 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 13530 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 13540 | average extrinsic reward (last 10 epochs): 0.062
# Epoch 13550 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 13560 | average extrinsic reward (last 10 epochs): 0.122
# Epoch 13570 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 13580 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 13590 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 13600 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 13610 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 13620 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 13630 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 13640 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 13650 | average extrinsic reward (last 10 epochs): 0.055
# Epoch 13660 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 13670 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 13680 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 13690 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 13700 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 13710 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 13720 | average extrinsic reward (last 10 epochs): 0.101
# Epoch 13730 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 13740 | average extrinsic reward (last 10 epochs): 0.127
# Epoch 13750 | average extrinsic reward (last 10 epochs): 0.126
# Epoch 13760 | average extrinsic reward (last 10 epochs): 0.107
# Epoch 13770 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 13780 | average extrinsic reward (last 10 epochs): 0.080
# Epoch 13790 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 13800 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 13810 | average extrinsic reward (last 10 epochs): 0.085
# Epoch 13820 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 13830 | average extrinsic reward (last 10 epochs): 0.065
# Epoch 13840 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 13850 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 13860 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 13870 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 13880 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 13890 | average extrinsic reward (last 10 epochs): 0.055
# Epoch 13900 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 13910 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 13920 | average extrinsic reward (last 10 epochs): 0.129
# Epoch 13930 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 13940 | average extrinsic reward (last 10 epochs): 0.054
# Epoch 13950 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 13960 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 13970 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 13980 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 13990 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 14000 | average extrinsic reward (last 10 epochs): 0.114
# Epoch 14010 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 14020 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 14030 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 14040 | average extrinsic reward (last 10 epochs): 0.047
# Epoch 14050 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 14060 | average extrinsic reward (last 10 epochs): 0.055
# Epoch 14070 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 14080 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 14090 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 14100 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 14110 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 14120 | average extrinsic reward (last 10 epochs): 0.089
# Epoch 14130 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 14140 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 14150 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 14160 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 14170 | average extrinsic reward (last 10 epochs): 0.102
# Epoch 14180 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 14190 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 14200 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 14210 | average extrinsic reward (last 10 epochs): 0.059
# Epoch 14220 | average extrinsic reward (last 10 epochs): 0.053
# Epoch 14230 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 14240 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 14250 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 14260 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 14270 | average extrinsic reward (last 10 epochs): 0.099
# Epoch 14280 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 14290 | average extrinsic reward (last 10 epochs): 0.114
# Epoch 14300 | average extrinsic reward (last 10 epochs): 0.063
# Epoch 14310 | average extrinsic reward (last 10 epochs): 0.140
# Epoch 14320 | average extrinsic reward (last 10 epochs): 0.113
# Epoch 14330 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 14340 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 14350 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 14360 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 14370 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 14380 | average extrinsic reward (last 10 epochs): 0.096
# Epoch 14390 | average extrinsic reward (last 10 epochs): 0.104
# Epoch 14400 | average extrinsic reward (last 10 epochs): 0.115
# Epoch 14410 | average extrinsic reward (last 10 epochs): 0.110
# Epoch 14420 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 14430 | average extrinsic reward (last 10 epochs): 0.073
# Epoch 14440 | average extrinsic reward (last 10 epochs): 0.058
# Epoch 14450 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 14460 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 14470 | average extrinsic reward (last 10 epochs): 0.100
# Epoch 14480 | average extrinsic reward (last 10 epochs): 0.058
# Epoch 14490 | average extrinsic reward (last 10 epochs): 0.090
# Epoch 14500 | average extrinsic reward (last 10 epochs): 0.078
# Epoch 14510 | average extrinsic reward (last 10 epochs): 0.060
# Epoch 14520 | average extrinsic reward (last 10 epochs): 0.095
# Epoch 14530 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 14540 | average extrinsic reward (last 10 epochs): 0.049
# Epoch 14550 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 14560 | average extrinsic reward (last 10 epochs): 0.127
# Epoch 14570 | average extrinsic reward (last 10 epochs): 0.106
# Epoch 14580 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 14590 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 14600 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 14610 | average extrinsic reward (last 10 epochs): 0.061
# Epoch 14620 | average extrinsic reward (last 10 epochs): 0.070
# Epoch 14630 | average extrinsic reward (last 10 epochs): 0.108
# Epoch 14640 | average extrinsic reward (last 10 epochs): 0.083
# Epoch 14650 | average extrinsic reward (last 10 epochs): 0.071
# Epoch 14660 | average extrinsic reward (last 10 epochs): 0.088
# Epoch 14670 | average extrinsic reward (last 10 epochs): 0.098
# Epoch 14680 | average extrinsic reward (last 10 epochs): 0.093
# Epoch 14690 | average extrinsic reward (last 10 epochs): 0.067
# Epoch 14700 | average extrinsic reward (last 10 epochs): 0.114
# Epoch 14710 | average extrinsic reward (last 10 epochs): 0.076
# Epoch 14720 | average extrinsic reward (last 10 epochs): 0.059
# Epoch 14730 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 14740 | average extrinsic reward (last 10 epochs): 0.084
# Epoch 14750 | average extrinsic reward (last 10 epochs): 0.091
# Epoch 14760 | average extrinsic reward (last 10 epochs): 0.057
# Epoch 14770 | average extrinsic reward (last 10 epochs): 0.105
# Epoch 14780 | average extrinsic reward (last 10 epochs): 0.079
# Epoch 14790 | average extrinsic reward (last 10 epochs): 0.068
# Epoch 14800 | average extrinsic reward (last 10 epochs): 0.107
# Epoch 14810 | average extrinsic reward (last 10 epochs): 0.055
# Epoch 14820 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 14830 | average extrinsic reward (last 10 epochs): 0.086
# Epoch 14840 | average extrinsic reward (last 10 epochs): 0.097
# Epoch 14850 | average extrinsic reward (last 10 epochs): 0.052
# Epoch 14860 | average extrinsic reward (last 10 epochs): 0.075
# Epoch 14870 | average extrinsic reward (last 10 epochs): 0.092
# Epoch 14880 | average extrinsic reward (last 10 epochs): 0.066
# Epoch 14890 | average extrinsic reward (last 10 epochs): 0.103
# Epoch 14900 | average extrinsic reward (last 10 epochs): 0.074
# Epoch 14910 | average extrinsic reward (last 10 epochs): 0.082
# Epoch 14920 | average extrinsic reward (last 10 epochs): 0.087
# Epoch 14930 | average extrinsic reward (last 10 epochs): 0.077
# Epoch 14940 | average extrinsic reward (last 10 epochs): 0.055
# Epoch 14950 | average extrinsic reward (last 10 epochs): 0.081
# Epoch 14960 | average extrinsic reward (last 10 epochs): 0.089
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 148
#     145 epoch_rewards = []
#     147 for _ in range(args.num_steps):
# --> 148     action_dist, goals, states, value_m, value_w = feudalnet(
#     149         obs, goals, states, masks[-1]
#     150     )
#     151     actions, logp, entropy = take_action(action_dist)
#     152     obs, reward, terminated, truncated, infos = envs.step(actions)
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\luk27\Downloads\feudalnets-pytorch-master (1)\feudalnets-pytorch-master\feudalnet.py:68, in FeudalNetwork.forward(self, x, goals, states, mask, save)
#      50 """A forward pass through the whole feudal network.
#      51
#      52 Order of operations:
#    (...)
#      65                            store rnn states. Defaults to True.
#      66 """
#      67 x = self.preprocessor(x)
# ---> 68 z = self.percept(x)
#      70 goal, hidden_m, state, value_m = self.manager(
#      71     z, self.hidden_m, mask)
#      73 # Ensure that we only have a list of size 2*c + 1, and we use FiLo
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\luk27\Downloads\feudalnets-pytorch-master (1)\feudalnets-pytorch-master\feudalnet.py:135, in Perception.forward(self, x)
#     134 def forward(self, x):
# --> 135     return self.percept(x)
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\luk27\anaconda3\envs\interp\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
