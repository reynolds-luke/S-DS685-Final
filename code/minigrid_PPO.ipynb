# %%
# !pip uninstall gym -y
# !pip install gymnasium minigrid torch numpy


import numpy as np

# Patch numpy to add bool8 for compatibility
if not hasattr(np, 'bool8'):
    np.bool8 = np.bool_
# Out:
# Found existing installation: gym 0.26.2
# Uninstalling gym-0.26.2:
#   Successfully uninstalled gym-0.26.2
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Collecting minigrid
#   Downloading minigrid-3.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: pygame>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from minigrid) (2.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading minigrid-3.0.0-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 kB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, minigrid, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed minigrid-3.0.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
from torch.distributions import Categorical
from minigrid.wrappers import RGBImgPartialObsWrapper, ImgObsWrapper

# Hyperparameters
GAMMA = 0.99
CLIP_EPS = 0.2
LR = 2.5e-4
EPOCHS = 4
BATCH_SIZE = 64
STEPS_PER_UPDATE = 2048

def make_env():
    env = gym.make("MiniGrid-Empty-Random-5x5-v0", render_mode=None)
    env = RGBImgPartialObsWrapper(env)
    env = ImgObsWrapper(env)
    return env

class ActorCritic(nn.Module):
    def __init__(self, input_shape, n_actions):
        super().__init__()
        c, h, w = input_shape
        self.conv = nn.Sequential(
            nn.Conv2d(c, 16, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.Flatten()
        )
        conv_out_size = 32 * h * w
        self.policy = nn.Sequential(
            nn.Linear(conv_out_size, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )
        self.value = nn.Sequential(
            nn.Linear(conv_out_size, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        x = x.float() / 255.0
        x = self.conv(x)
        return self.policy(x), self.value(x)

def compute_returns_and_advantages(rewards, dones, values, gamma=GAMMA):
    returns, advs = [], []
    G = 0
    A = 0
    next_value = 0
    for i in reversed(range(len(rewards))):
        mask = 1.0 - dones[i]
        delta = rewards[i] + gamma * next_value * mask - values[i]
        A = delta + gamma * 0.95 * A * mask
        G = rewards[i] + gamma * G * mask
        returns.insert(0, G)
        advs.insert(0, A)
        next_value = values[i]
    return torch.tensor(returns), torch.tensor(advs)

def ppo_update(model, optimizer, obs, actions, log_probs_old, returns, advantages):
    for _ in range(EPOCHS):
        idx = np.random.permutation(len(obs))
        for start in range(0, len(obs), BATCH_SIZE):
            end = start + BATCH_SIZE
            batch_idx = idx[start:end]

            obs_batch = torch.tensor(obs[batch_idx], dtype=torch.float32).permute(0, 3, 1, 2)
            actions_batch = torch.tensor(actions[batch_idx])
            old_log_probs = torch.tensor(log_probs_old[batch_idx])
            returns_batch = returns[batch_idx]
            advantages_batch = advantages[batch_idx]

            logits, values = model(obs_batch)
            dist = Categorical(logits=logits)
            log_probs = dist.log_prob(actions_batch)

            ratio = torch.exp(log_probs - old_log_probs)
            surr1 = ratio * advantages_batch
            surr2 = torch.clamp(ratio, 1.0 - CLIP_EPS, 1.0 + CLIP_EPS) * advantages_batch
            actor_loss = -torch.min(surr1, surr2).mean()
            critic_loss = (returns_batch - values.squeeze()).pow(2).mean()
            loss = actor_loss + 0.5 * critic_loss

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def train():
    env = make_env()
    obs_shape = env.observation_space.shape
    n_actions = env.action_space.n

    model = ActorCritic((obs_shape[2], obs_shape[0], obs_shape[1]), n_actions)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)

    obs, _ = env.reset()
    obs = obs.astype(np.uint8)
    episode_rewards = []
    ep_reward = 0
    episode_count = 0
    step_count = 0

    for update in range(1000):
        obs_list, actions, log_probs, rewards, dones, values = [], [], [], [], [], []

        for _ in range(STEPS_PER_UPDATE):
            obs_tensor = torch.tensor(obs).permute(2, 0, 1).unsqueeze(0).float() / 255.0
            logits, value = model(obs_tensor)
            dist = Categorical(logits=logits)
            action = dist.sample()

            next_obs, reward, terminated, truncated, _ = env.step(action.item())
            done = terminated or truncated

            obs_list.append(obs)
            actions.append(action.item())
            log_probs.append(dist.log_prob(action).item())
            values.append(value.item())
            rewards.append(reward)
            dones.append(done)
            obs = next_obs.astype(np.uint8)
            ep_reward += reward
            step_count += 1

            if done:
                episode_count += 1
                print(f"episode = {episode_count} | steps = {step_count}")
                obs, _ = env.reset()
                obs = obs.astype(np.uint8)
                episode_rewards.append(ep_reward)
                ep_reward = 0
                step_count = 0

        returns, advantages = compute_returns_and_advantages(rewards, dones, values)
        obs_array = np.array(obs_list)
        actions = np.array(actions)
        log_probs = np.array(log_probs)

        ppo_update(model, optimizer, obs_array, actions, log_probs, returns, advantages)

        if update % 10 == 0:
            avg_reward = np.mean(episode_rewards[-10:]) if episode_rewards else 0
            print(f"Update {update}, Average Reward: {avg_reward:.2f}")

if __name__ == "__main__":
    train()
# Out:
# episode = 1 | steps = 100
# episode = 2 | steps = 100
# episode = 3 | steps = 100
# episode = 4 | steps = 11
# episode = 5 | steps = 6
# episode = 6 | steps = 100
# episode = 7 | steps = 80
# episode = 8 | steps = 2
# episode = 9 | steps = 100
# episode = 10 | steps = 63
# episode = 11 | steps = 100
# episode = 12 | steps = 27
# episode = 13 | steps = 12
# episode = 14 | steps = 7
# episode = 15 | steps = 100
# episode = 16 | steps = 100
# episode = 17 | steps = 100
# episode = 18 | steps = 18
# episode = 19 | steps = 100
# episode = 20 | steps = 100
# episode = 21 | steps = 100
# episode = 22 | steps = 100
# episode = 23 | steps = 1
# episode = 24 | steps = 56
# episode = 25 | steps = 100
# episode = 26 | steps = 100
# episode = 27 | steps = 14
# episode = 28 | steps = 21
# episode = 29 | steps = 100
# episode = 30 | steps = 100
# Update 0, Average Reward: 0.32
# episode = 31 | steps = 100
# episode = 32 | steps = 76
# episode = 33 | steps = 1
# episode = 34 | steps = 78
# episode = 35 | steps = 18
# episode = 36 | steps = 100
# episode = 37 | steps = 100
# episode = 38 | steps = 31
# episode = 39 | steps = 64
# episode = 40 | steps = 100
# episode = 41 | steps = 65
# episode = 42 | steps = 100
# episode = 43 | steps = 100
# episode = 44 | steps = 11
# episode = 45 | steps = 100
# episode = 46 | steps = 100
# episode = 47 | steps = 37
# episode = 48 | steps = 100
# episode = 49 | steps = 100
# episode = 50 | steps = 83
# episode = 51 | steps = 100
# episode = 52 | steps = 100
# episode = 53 | steps = 100
# episode = 54 | steps = 100
# episode = 55 | steps = 100
# episode = 56 | steps = 33
# episode = 57 | steps = 100
# episode = 58 | steps = 53
# episode = 59 | steps = 100
# episode = 60 | steps = 22
# episode = 61 | steps = 100
# episode = 62 | steps = 40
# episode = 63 | steps = 6
# episode = 64 | steps = 100
# episode = 65 | steps = 100
# episode = 66 | steps = 100
# episode = 67 | steps = 100
# episode = 68 | steps = 100
# episode = 69 | steps = 100
# episode = 70 | steps = 18
# episode = 71 | steps = 22
# episode = 72 | steps = 100
# episode = 73 | steps = 15
# episode = 74 | steps = 100
# episode = 75 | steps = 100
# episode = 76 | steps = 67
# episode = 77 | steps = 100
# episode = 78 | steps = 51
# episode = 79 | steps = 75
# episode = 80 | steps = 16
# episode = 81 | steps = 100
# episode = 82 | steps = 77
# episode = 83 | steps = 100
# episode = 84 | steps = 100
# episode = 85 | steps = 100
# episode = 86 | steps = 25
# episode = 87 | steps = 100
# episode = 88 | steps = 100
# episode = 89 | steps = 19
# episode = 90 | steps = 100
# episode = 91 | steps = 100
# episode = 92 | steps = 25
# episode = 93 | steps = 100
# episode = 94 | steps = 100
# episode = 95 | steps = 34
# episode = 96 | steps = 27
# episode = 97 | steps = 100
# episode = 98 | steps = 49
# episode = 99 | steps = 48
# episode = 100 | steps = 13
# episode = 101 | steps = 100
# episode = 102 | steps = 50
# episode = 103 | steps = 100
# episode = 104 | steps = 27
# episode = 105 | steps = 100
# episode = 106 | steps = 87
# episode = 107 | steps = 44
# episode = 108 | steps = 81
# episode = 109 | steps = 67
# episode = 110 | steps = 22
# episode = 111 | steps = 30
# episode = 112 | steps = 26
# episode = 113 | steps = 100
# episode = 114 | steps = 9
# episode = 115 | steps = 83
# episode = 116 | steps = 50
# episode = 117 | steps = 11
# episode = 118 | steps = 50
# episode = 119 | steps = 100
# episode = 120 | steps = 34
# episode = 121 | steps = 100
# episode = 122 | steps = 17
# episode = 123 | steps = 100
# episode = 124 | steps = 85
# episode = 125 | steps = 100
# episode = 126 | steps = 89
# episode = 127 | steps = 62
# episode = 128 | steps = 60
# episode = 129 | steps = 88
# episode = 130 | steps = 8
# episode = 131 | steps = 27
# episode = 132 | steps = 61
# episode = 133 | steps = 100
# episode = 134 | steps = 100
# episode = 135 | steps = 64
# episode = 136 | steps = 100
# episode = 137 | steps = 48
# episode = 138 | steps = 100
# episode = 139 | steps = 100
# episode = 140 | steps = 100
# episode = 141 | steps = 79
# episode = 142 | steps = 100
# episode = 143 | steps = 100
# episode = 144 | steps = 78
# episode = 145 | steps = 85
# episode = 146 | steps = 34
# episode = 147 | steps = 15
# episode = 148 | steps = 100
# episode = 149 | steps = 24
# episode = 150 | steps = 100
# episode = 151 | steps = 100
# episode = 152 | steps = 100
# episode = 153 | steps = 100
# episode = 154 | steps = 49
# episode = 155 | steps = 41
# episode = 156 | steps = 100
# episode = 157 | steps = 59
# episode = 158 | steps = 100
# episode = 159 | steps = 10
# episode = 160 | steps = 91
# episode = 161 | steps = 100
# episode = 162 | steps = 100
# episode = 163 | steps = 100
# episode = 164 | steps = 100
# episode = 165 | steps = 5
# episode = 166 | steps = 100
# episode = 167 | steps = 4
# episode = 168 | steps = 100
# episode = 169 | steps = 100
# episode = 170 | steps = 35
# episode = 171 | steps = 100
# episode = 172 | steps = 100
# episode = 173 | steps = 100
# episode = 174 | steps = 100
# episode = 175 | steps = 55
# episode = 176 | steps = 90
# episode = 177 | steps = 100
# episode = 178 | steps = 46
# episode = 179 | steps = 100
# episode = 180 | steps = 39
# episode = 181 | steps = 100
# episode = 182 | steps = 58
# episode = 183 | steps = 71
# episode = 184 | steps = 100
# episode = 185 | steps = 100
# episode = 186 | steps = 100
# episode = 187 | steps = 100
# episode = 188 | steps = 100
# episode = 189 | steps = 73
# episode = 190 | steps = 31
# episode = 191 | steps = 100
# episode = 192 | steps = 21
# episode = 193 | steps = 100
# episode = 194 | steps = 54
# episode = 195 | steps = 41
# episode = 196 | steps = 100
# episode = 197 | steps = 100
# episode = 198 | steps = 100
# episode = 199 | steps = 11
# episode = 200 | steps = 100
# episode = 201 | steps = 100
# episode = 202 | steps = 100
# episode = 203 | steps = 27
# episode = 204 | steps = 100
# episode = 205 | steps = 100
# episode = 206 | steps = 4
# episode = 207 | steps = 100
# episode = 208 | steps = 100
# episode = 209 | steps = 100
# episode = 210 | steps = 33
# episode = 211 | steps = 100
# episode = 212 | steps = 100
# episode = 213 | steps = 29
# episode = 214 | steps = 17
# episode = 215 | steps = 12
# episode = 216 | steps = 79
# episode = 217 | steps = 6
# episode = 218 | steps = 100
# episode = 219 | steps = 100
# episode = 220 | steps = 19
# episode = 221 | steps = 58
# episode = 222 | steps = 99
# episode = 223 | steps = 91
# episode = 224 | steps = 86
# episode = 225 | steps = 100
# episode = 226 | steps = 2
# episode = 227 | steps = 79
# episode = 228 | steps = 50
# episode = 229 | steps = 7
# episode = 230 | steps = 100
# episode = 231 | steps = 100
# episode = 232 | steps = 54
# episode = 233 | steps = 50
# episode = 234 | steps = 100
# episode = 235 | steps = 100
# episode = 236 | steps = 100
# episode = 237 | steps = 100
# episode = 238 | steps = 12
# episode = 239 | steps = 24
# episode = 240 | steps = 100
# episode = 241 | steps = 95
# episode = 242 | steps = 100
# episode = 243 | steps = 21
# episode = 244 | steps = 90
# episode = 245 | steps = 100
# episode = 246 | steps = 36
# episode = 247 | steps = 100
# episode = 248 | steps = 87
# episode = 249 | steps = 100
# episode = 250 | steps = 70
# episode = 251 | steps = 100
# episode = 252 | steps = 85
# episode = 253 | steps = 34
# episode = 254 | steps = 90
# episode = 255 | steps = 29
# episode = 256 | steps = 66
# episode = 257 | steps = 55
# episode = 258 | steps = 100
# episode = 259 | steps = 43
# episode = 260 | steps = 87
# episode = 261 | steps = 100
# episode = 262 | steps = 100
# episode = 263 | steps = 100
# episode = 264 | steps = 2
# episode = 265 | steps = 100
# episode = 266 | steps = 68
# episode = 267 | steps = 40
# episode = 268 | steps = 100
# episode = 269 | steps = 52
# episode = 270 | steps = 100
# episode = 271 | steps = 100
# episode = 272 | steps = 100
# episode = 273 | steps = 100
# episode = 274 | steps = 100
# episode = 275 | steps = 100
# episode = 276 | steps = 100
# episode = 277 | steps = 62
# episode = 278 | steps = 100
# episode = 279 | steps = 51
# episode = 280 | steps = 100
# episode = 281 | steps = 100
# episode = 282 | steps = 7
# episode = 283 | steps = 98
# episode = 284 | steps = 100
# episode = 285 | steps = 32
# episode = 286 | steps = 10
# episode = 287 | steps = 100
# episode = 288 | steps = 15
# episode = 289 | steps = 100
# episode = 290 | steps = 12
# episode = 291 | steps = 81
# episode = 292 | steps = 63
# episode = 293 | steps = 3
# episode = 294 | steps = 25
# episode = 295 | steps = 100
# episode = 296 | steps = 100
# episode = 297 | steps = 100
# episode = 298 | steps = 60
# episode = 299 | steps = 100
# episode = 300 | steps = 58
# episode = 301 | steps = 23
# episode = 302 | steps = 24
# episode = 303 | steps = 100
# episode = 304 | steps = 52
# episode = 305 | steps = 100
# episode = 306 | steps = 100
# episode = 307 | steps = 11
# episode = 308 | steps = 43
# episode = 309 | steps = 16
# episode = 310 | steps = 2
# episode = 311 | steps = 31
# episode = 312 | steps = 100
# episode = 313 | steps = 100
# episode = 314 | steps = 11
# episode = 315 | steps = 98
# episode = 316 | steps = 100
# episode = 317 | steps = 44
# Update 10, Average Reward: 0.48
# episode = 318 | steps = 62
# episode = 319 | steps = 100
# episode = 320 | steps = 10
# episode = 321 | steps = 100
# episode = 322 | steps = 94
# episode = 323 | steps = 100
# episode = 324 | steps = 100
# episode = 325 | steps = 100
# episode = 326 | steps = 100
# episode = 327 | steps = 100
# episode = 328 | steps = 100
# episode = 329 | steps = 100
# episode = 330 | steps = 49
# episode = 331 | steps = 57
# episode = 332 | steps = 86
# episode = 333 | steps = 100
# episode = 334 | steps = 100
# episode = 335 | steps = 100
# episode = 336 | steps = 100
# episode = 337 | steps = 58
# episode = 338 | steps = 19
# episode = 339 | steps = 1
# episode = 340 | steps = 69
# episode = 341 | steps = 100
# episode = 342 | steps = 100
# episode = 343 | steps = 100
# episode = 344 | steps = 80
# episode = 345 | steps = 15
# episode = 346 | steps = 100
# episode = 347 | steps = 12
# episode = 348 | steps = 48
# episode = 349 | steps = 100
# episode = 350 | steps = 12
# episode = 351 | steps = 100
# episode = 352 | steps = 2
# episode = 353 | steps = 100
# episode = 354 | steps = 85
# episode = 355 | steps = 100
# episode = 356 | steps = 100
# episode = 357 | steps = 6
# episode = 358 | steps = 100
# episode = 359 | steps = 86
# episode = 360 | steps = 42
# episode = 361 | steps = 100
# episode = 362 | steps = 100
# episode = 363 | steps = 100
# episode = 364 | steps = 100
# episode = 365 | steps = 100
# episode = 366 | steps = 100
# episode = 367 | steps = 100
# episode = 368 | steps = 100
# episode = 369 | steps = 77
# episode = 370 | steps = 38
# episode = 371 | steps = 100
# episode = 372 | steps = 73
# episode = 373 | steps = 100
# episode = 374 | steps = 100
# episode = 375 | steps = 35
# episode = 376 | steps = 100
# episode = 377 | steps = 100
# episode = 378 | steps = 32
# episode = 379 | steps = 100
# episode = 380 | steps = 100
# episode = 381 | steps = 100
# episode = 382 | steps = 100
# episode = 383 | steps = 100
# episode = 384 | steps = 100
# episode = 385 | steps = 100
# episode = 386 | steps = 100
# episode = 387 | steps = 61
# episode = 388 | steps = 27
# episode = 389 | steps = 65
# episode = 390 | steps = 70
# episode = 391 | steps = 22
# episode = 392 | steps = 1
# episode = 393 | steps = 100
# episode = 394 | steps = 100
# episode = 395 | steps = 100
# episode = 396 | steps = 100
# episode = 397 | steps = 18
# episode = 398 | steps = 100
# episode = 399 | steps = 33
# episode = 400 | steps = 31
# episode = 401 | steps = 100
# episode = 402 | steps = 100
# episode = 403 | steps = 100
# episode = 404 | steps = 100
# episode = 405 | steps = 64
# episode = 406 | steps = 95
# episode = 407 | steps = 2
# episode = 408 | steps = 100
# episode = 409 | steps = 64
# episode = 410 | steps = 100
# episode = 411 | steps = 24
# episode = 412 | steps = 100
# episode = 413 | steps = 100
# episode = 414 | steps = 48
# episode = 415 | steps = 61
# episode = 416 | steps = 100
# episode = 417 | steps = 73
# episode = 418 | steps = 23
# episode = 419 | steps = 100
# episode = 420 | steps = 100
# episode = 421 | steps = 10
# episode = 422 | steps = 53
# episode = 423 | steps = 100
# episode = 424 | steps = 100
# episode = 425 | steps = 100
# episode = 426 | steps = 100
# episode = 427 | steps = 100
# episode = 428 | steps = 15
# episode = 429 | steps = 100
# episode = 430 | steps = 100
# episode = 431 | steps = 18
# episode = 432 | steps = 100
# episode = 433 | steps = 6
# episode = 434 | steps = 100
# episode = 435 | steps = 2
# episode = 436 | steps = 100
# episode = 437 | steps = 47
# episode = 438 | steps = 100
# episode = 439 | steps = 100
# episode = 440 | steps = 51
# episode = 441 | steps = 1
# episode = 442 | steps = 12
# episode = 443 | steps = 50
# episode = 444 | steps = 100
# episode = 445 | steps = 61
# episode = 446 | steps = 55
# episode = 447 | steps = 54
# episode = 448 | steps = 74
# episode = 449 | steps = 7
# episode = 450 | steps = 100
# episode = 451 | steps = 100
# episode = 452 | steps = 100
# episode = 453 | steps = 100
# episode = 454 | steps = 22
# episode = 455 | steps = 94
# episode = 456 | steps = 100
# episode = 457 | steps = 9
# episode = 458 | steps = 100
# episode = 459 | steps = 29
# episode = 460 | steps = 100
# episode = 461 | steps = 50
# episode = 462 | steps = 100
# episode = 463 | steps = 100
# episode = 464 | steps = 13
# episode = 465 | steps = 100
# episode = 466 | steps = 99
# episode = 467 | steps = 100
# episode = 468 | steps = 100
# episode = 469 | steps = 100
# episode = 470 | steps = 80
# episode = 471 | steps = 100
# episode = 472 | steps = 100
# episode = 473 | steps = 100
# episode = 474 | steps = 100
# episode = 475 | steps = 7
# episode = 476 | steps = 21
# episode = 477 | steps = 100
# episode = 478 | steps = 83
# episode = 479 | steps = 100
# episode = 480 | steps = 100
# episode = 481 | steps = 100
# episode = 482 | steps = 100
# episode = 483 | steps = 100
# episode = 484 | steps = 100
# episode = 485 | steps = 57
# episode = 486 | steps = 36
# episode = 487 | steps = 95
# episode = 488 | steps = 13
# episode = 489 | steps = 7
# episode = 490 | steps = 100
# episode = 491 | steps = 30
# episode = 492 | steps = 100
# episode = 493 | steps = 100
# episode = 494 | steps = 100
# episode = 495 | steps = 100
# episode = 496 | steps = 22
# episode = 497 | steps = 100
# episode = 498 | steps = 100
# episode = 499 | steps = 100
# episode = 500 | steps = 100
# episode = 501 | steps = 100
# episode = 502 | steps = 37
# episode = 503 | steps = 100
# episode = 504 | steps = 30
# episode = 505 | steps = 100
# episode = 506 | steps = 22
# episode = 507 | steps = 100
# episode = 508 | steps = 100
# episode = 509 | steps = 83
# episode = 510 | steps = 83
# episode = 511 | steps = 100
# episode = 512 | steps = 100
# episode = 513 | steps = 100
# episode = 514 | steps = 100
# episode = 515 | steps = 86
# episode = 516 | steps = 26
# episode = 517 | steps = 45
# episode = 518 | steps = 100
# episode = 519 | steps = 68
# episode = 520 | steps = 100
# episode = 521 | steps = 99
# episode = 522 | steps = 100
# episode = 523 | steps = 16
# episode = 524 | steps = 100
# episode = 525 | steps = 100
# episode = 526 | steps = 100
# episode = 527 | steps = 100
# episode = 528 | steps = 100
# episode = 529 | steps = 76
# episode = 530 | steps = 29
# episode = 531 | steps = 20
# episode = 532 | steps = 30
# episode = 533 | steps = 100
# episode = 534 | steps = 88
# episode = 535 | steps = 39
# episode = 536 | steps = 33
# episode = 537 | steps = 100
# episode = 538 | steps = 100
# episode = 539 | steps = 100
# episode = 540 | steps = 77
# episode = 541 | steps = 32
# episode = 542 | steps = 100
# episode = 543 | steps = 73
# episode = 544 | steps = 72
# episode = 545 | steps = 71
# episode = 546 | steps = 100
# episode = 547 | steps = 44
# episode = 548 | steps = 38
# episode = 549 | steps = 88
# episode = 550 | steps = 3
# episode = 551 | steps = 8
# episode = 552 | steps = 49
# episode = 553 | steps = 100
# episode = 554 | steps = 100
# episode = 555 | steps = 46
# episode = 556 | steps = 63
# episode = 557 | steps = 59
# episode = 558 | steps = 100
# episode = 559 | steps = 100
# episode = 560 | steps = 4
# episode = 561 | steps = 30
# episode = 562 | steps = 100
# episode = 563 | steps = 54
# episode = 564 | steps = 42
# episode = 565 | steps = 100
# episode = 566 | steps = 21
# episode = 567 | steps = 100
# episode = 568 | steps = 42
# episode = 569 | steps = 100
# episode = 570 | steps = 100
# episode = 571 | steps = 20
# episode = 572 | steps = 83
# episode = 573 | steps = 16
# episode = 574 | steps = 81
# episode = 575 | steps = 50
# episode = 576 | steps = 57
# episode = 577 | steps = 16
# episode = 578 | steps = 38
# episode = 579 | steps = 81
# episode = 580 | steps = 100
# episode = 581 | steps = 100
# episode = 582 | steps = 100
# episode = 583 | steps = 7
# episode = 584 | steps = 100
# episode = 585 | steps = 36
# episode = 586 | steps = 100
# episode = 587 | steps = 100
# episode = 588 | steps = 5
# episode = 589 | steps = 82
# episode = 590 | steps = 100
# episode = 591 | steps = 11
# episode = 592 | steps = 100
# episode = 593 | steps = 100
# episode = 594 | steps = 100
# Update 20, Average Reward: 0.28
# episode = 595 | steps = 100
# episode = 596 | steps = 100
# episode = 597 | steps = 100
# episode = 598 | steps = 100
# episode = 599 | steps = 36
# episode = 600 | steps = 100
# episode = 601 | steps = 100
# episode = 602 | steps = 100
# episode = 603 | steps = 3
# episode = 604 | steps = 12
# episode = 605 | steps = 74
# episode = 606 | steps = 38
# episode = 607 | steps = 84
# episode = 608 | steps = 100
# episode = 609 | steps = 21
# episode = 610 | steps = 9
# episode = 611 | steps = 100
# episode = 612 | steps = 100
# episode = 613 | steps = 100
# episode = 614 | steps = 100
# episode = 615 | steps = 100
# episode = 616 | steps = 27
# episode = 617 | steps = 35
# episode = 618 | steps = 100
# episode = 619 | steps = 52
# episode = 620 | steps = 3
# episode = 621 | steps = 100
# episode = 622 | steps = 92
# episode = 623 | steps = 100
# episode = 624 | steps = 100
# episode = 625 | steps = 100
# episode = 626 | steps = 36
# episode = 627 | steps = 100
# episode = 628 | steps = 100
# episode = 629 | steps = 62
# episode = 630 | steps = 23
# episode = 631 | steps = 100
# episode = 632 | steps = 43
# episode = 633 | steps = 13
# episode = 634 | steps = 100
# episode = 635 | steps = 100
# episode = 636 | steps = 100
# episode = 637 | steps = 100
# episode = 638 | steps = 58
# episode = 639 | steps = 100
# episode = 640 | steps = 34
# episode = 641 | steps = 66
# episode = 642 | steps = 100
# episode = 643 | steps = 100
# episode = 644 | steps = 2
# episode = 645 | steps = 42
# episode = 646 | steps = 100
# episode = 647 | steps = 100
# episode = 648 | steps = 77
# episode = 649 | steps = 51
# episode = 650 | steps = 100
# episode = 651 | steps = 12
# episode = 652 | steps = 100
# episode = 653 | steps = 57
# episode = 654 | steps = 54
# episode = 655 | steps = 40
# episode = 656 | steps = 25
# episode = 657 | steps = 69
# episode = 658 | steps = 34
# episode = 659 | steps = 52
# episode = 660 | steps = 100
# episode = 661 | steps = 56
# episode = 662 | steps = 100
# episode = 663 | steps = 66
# episode = 664 | steps = 45
# episode = 665 | steps = 53
# episode = 666 | steps = 37
# episode = 667 | steps = 3
# episode = 668 | steps = 60
# episode = 669 | steps = 100
# episode = 670 | steps = 11
# episode = 671 | steps = 18
# episode = 672 | steps = 34
# episode = 673 | steps = 6
# episode = 674 | steps = 61
# episode = 675 | steps = 28
# episode = 676 | steps = 60
# episode = 677 | steps = 3
# episode = 678 | steps = 79
# episode = 679 | steps = 100
# episode = 680 | steps = 100
# episode = 681 | steps = 3
# episode = 682 | steps = 100
# episode = 683 | steps = 49
# episode = 684 | steps = 6
# episode = 685 | steps = 100
# episode = 686 | steps = 100
# episode = 687 | steps = 100
# episode = 688 | steps = 46
# episode = 689 | steps = 100
# episode = 690 | steps = 50
# episode = 691 | steps = 92
# episode = 692 | steps = 100
# episode = 693 | steps = 100
# episode = 694 | steps = 100
# episode = 695 | steps = 85
# episode = 696 | steps = 12
# episode = 697 | steps = 100
# episode = 698 | steps = 100
# episode = 699 | steps = 5
# episode = 700 | steps = 100
# episode = 701 | steps = 24
# episode = 702 | steps = 69
# episode = 703 | steps = 100
# episode = 704 | steps = 100
# episode = 705 | steps = 39
# episode = 706 | steps = 100
# episode = 707 | steps = 100
# episode = 708 | steps = 100
# episode = 709 | steps = 100
# episode = 710 | steps = 20
# episode = 711 | steps = 100
# episode = 712 | steps = 100
# episode = 713 | steps = 26
# episode = 714 | steps = 67
# episode = 715 | steps = 14
# episode = 716 | steps = 100
# episode = 717 | steps = 100
# episode = 718 | steps = 100
# episode = 719 | steps = 100
# episode = 720 | steps = 61
# episode = 721 | steps = 100
# episode = 722 | steps = 74
# episode = 723 | steps = 57
# episode = 724 | steps = 100
# episode = 725 | steps = 100
# episode = 726 | steps = 100
# episode = 727 | steps = 100
# episode = 728 | steps = 12
# episode = 729 | steps = 22
# episode = 730 | steps = 82
# episode = 731 | steps = 100
# episode = 732 | steps = 8
# episode = 733 | steps = 100
# episode = 734 | steps = 39
# episode = 735 | steps = 100
# episode = 736 | steps = 61
# episode = 737 | steps = 55
# episode = 738 | steps = 87
# episode = 739 | steps = 100
# episode = 740 | steps = 37
# episode = 741 | steps = 100
# episode = 742 | steps = 60
# episode = 743 | steps = 14
# episode = 744 | steps = 80
# episode = 745 | steps = 9
# episode = 746 | steps = 27
# episode = 747 | steps = 100
# episode = 748 | steps = 12
# episode = 749 | steps = 6
# episode = 750 | steps = 30
# episode = 751 | steps = 100
# episode = 752 | steps = 64
# episode = 753 | steps = 45
# episode = 754 | steps = 4
# episode = 755 | steps = 100
# episode = 756 | steps = 73
# episode = 757 | steps = 100
# episode = 758 | steps = 100
# episode = 759 | steps = 37
# episode = 760 | steps = 100
# episode = 761 | steps = 20
# episode = 762 | steps = 100
# episode = 763 | steps = 100
# episode = 764 | steps = 36
# episode = 765 | steps = 100
# episode = 766 | steps = 8
# episode = 767 | steps = 69
# episode = 768 | steps = 100
# episode = 769 | steps = 100
# episode = 770 | steps = 63
# episode = 771 | steps = 100
# episode = 772 | steps = 6
# episode = 773 | steps = 40
# episode = 774 | steps = 64
# episode = 775 | steps = 100
# episode = 776 | steps = 100
# episode = 777 | steps = 100
# episode = 778 | steps = 100
# episode = 779 | steps = 23
# episode = 780 | steps = 84
# episode = 781 | steps = 18
# episode = 782 | steps = 26
# episode = 783 | steps = 100
# episode = 784 | steps = 100
# episode = 785 | steps = 100
# episode = 786 | steps = 100
# episode = 787 | steps = 6
# episode = 788 | steps = 16
# episode = 789 | steps = 52
# episode = 790 | steps = 49
# episode = 791 | steps = 17
# episode = 792 | steps = 26
# episode = 793 | steps = 3
# episode = 794 | steps = 100
# episode = 795 | steps = 37
# episode = 796 | steps = 100
# episode = 797 | steps = 100
# episode = 798 | steps = 11
# episode = 799 | steps = 100
# episode = 800 | steps = 84
# episode = 801 | steps = 100
# episode = 802 | steps = 100
# episode = 803 | steps = 42
# episode = 804 | steps = 62
# episode = 805 | steps = 51
# episode = 806 | steps = 41
# episode = 807 | steps = 70
# episode = 808 | steps = 46
# episode = 809 | steps = 4
# episode = 810 | steps = 58
# episode = 811 | steps = 100
# episode = 812 | steps = 100
# episode = 813 | steps = 8
# episode = 814 | steps = 41
# episode = 815 | steps = 26
# episode = 816 | steps = 56
# episode = 817 | steps = 100
# episode = 818 | steps = 10
# episode = 819 | steps = 25
# episode = 820 | steps = 100
# episode = 821 | steps = 100
# episode = 822 | steps = 99
# episode = 823 | steps = 26
# episode = 824 | steps = 10
# episode = 825 | steps = 25
# episode = 826 | steps = 37
# episode = 827 | steps = 100
# episode = 828 | steps = 1
# episode = 829 | steps = 100
# episode = 830 | steps = 100
# episode = 831 | steps = 52
# episode = 832 | steps = 100
# episode = 833 | steps = 10
# episode = 834 | steps = 100
# episode = 835 | steps = 38
# episode = 836 | steps = 5
# episode = 837 | steps = 100
# episode = 838 | steps = 22
# episode = 839 | steps = 100
# episode = 840 | steps = 25
# episode = 841 | steps = 100
# episode = 842 | steps = 17
# episode = 843 | steps = 2
# episode = 844 | steps = 35
# episode = 845 | steps = 89
# episode = 846 | steps = 100
# episode = 847 | steps = 65
# episode = 848 | steps = 100
# episode = 849 | steps = 100
# episode = 850 | steps = 100
# episode = 851 | steps = 73
# episode = 852 | steps = 63
# episode = 853 | steps = 89
# episode = 854 | steps = 83
# episode = 855 | steps = 100
# episode = 856 | steps = 11
# episode = 857 | steps = 31
# episode = 858 | steps = 70
# episode = 859 | steps = 8
# episode = 860 | steps = 100
# episode = 861 | steps = 50
# episode = 862 | steps = 100
# episode = 863 | steps = 90
# episode = 864 | steps = 100
# episode = 865 | steps = 89
# episode = 866 | steps = 71
# episode = 867 | steps = 7
# episode = 868 | steps = 24
# episode = 869 | steps = 100
# episode = 870 | steps = 100
# episode = 871 | steps = 2
# episode = 872 | steps = 100
# episode = 873 | steps = 46
# episode = 874 | steps = 100
# episode = 875 | steps = 45
# episode = 876 | steps = 100
# episode = 877 | steps = 100
# episode = 878 | steps = 100
# episode = 879 | steps = 21
# episode = 880 | steps = 100
# episode = 881 | steps = 100
# episode = 882 | steps = 100
# episode = 883 | steps = 20
# episode = 884 | steps = 100
# episode = 885 | steps = 100
# episode = 886 | steps = 100
# episode = 887 | steps = 100
# episode = 888 | steps = 11
# episode = 889 | steps = 100
# episode = 890 | steps = 100
# episode = 891 | steps = 40
# episode = 892 | steps = 87
# episode = 893 | steps = 17
# episode = 894 | steps = 67
# episode = 895 | steps = 100
# episode = 896 | steps = 10
# episode = 897 | steps = 15
# episode = 898 | steps = 100
# episode = 899 | steps = 100
# episode = 900 | steps = 100
# episode = 901 | steps = 100
# episode = 902 | steps = 100
# Update 30, Average Reward: 0.31
# episode = 903 | steps = 100
# episode = 904 | steps = 100
# episode = 905 | steps = 100
# episode = 906 | steps = 95
# episode = 907 | steps = 100
# episode = 908 | steps = 38
# episode = 909 | steps = 100
# episode = 910 | steps = 83
# episode = 911 | steps = 100
# episode = 912 | steps = 100
# episode = 913 | steps = 100
# episode = 914 | steps = 100
# episode = 915 | steps = 100
# episode = 916 | steps = 100
# episode = 917 | steps = 100
# episode = 918 | steps = 100
# episode = 919 | steps = 13
# episode = 920 | steps = 3
# episode = 921 | steps = 61
# episode = 922 | steps = 100
# episode = 923 | steps = 100
# episode = 924 | steps = 84
# episode = 925 | steps = 47
# episode = 926 | steps = 100
# episode = 927 | steps = 100
# episode = 928 | steps = 100
# episode = 929 | steps = 5
# episode = 930 | steps = 30
# episode = 931 | steps = 100
# episode = 932 | steps = 74
# episode = 933 | steps = 45
# episode = 934 | steps = 11
# episode = 935 | steps = 48
# episode = 936 | steps = 50
# episode = 937 | steps = 100
# episode = 938 | steps = 100
# episode = 939 | steps = 100
# episode = 940 | steps = 100
# episode = 941 | steps = 100
# episode = 942 | steps = 15
# episode = 943 | steps = 98
# episode = 944 | steps = 100
# episode = 945 | steps = 100
# episode = 946 | steps = 23
# episode = 947 | steps = 100
# episode = 948 | steps = 36
# episode = 949 | steps = 12
# episode = 950 | steps = 100
# episode = 951 | steps = 49
# episode = 952 | steps = 100
# episode = 953 | steps = 100
# episode = 954 | steps = 91
# episode = 955 | steps = 100
# episode = 956 | steps = 100
# episode = 957 | steps = 34
# episode = 958 | steps = 100
# episode = 959 | steps = 100
# episode = 960 | steps = 100
# episode = 961 | steps = 21
# episode = 962 | steps = 83
# episode = 963 | steps = 100
# episode = 964 | steps = 41
# episode = 965 | steps = 67
# episode = 966 | steps = 25
# episode = 967 | steps = 100
# episode = 968 | steps = 100
# episode = 969 | steps = 47
# episode = 970 | steps = 100
# episode = 971 | steps = 100
# episode = 972 | steps = 83
# episode = 973 | steps = 100
# episode = 974 | steps = 100
# episode = 975 | steps = 100
# episode = 976 | steps = 56
# episode = 977 | steps = 80
# episode = 978 | steps = 100
# episode = 979 | steps = 100
# episode = 980 | steps = 21
# episode = 981 | steps = 100
